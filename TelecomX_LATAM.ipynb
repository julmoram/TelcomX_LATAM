# %% [markdown]
# <a href="https://colab.research.google.com/github/julmoram/TelcomX_LATAM/blob/main/TelecomX_LATAM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📌 Extracción

# %%
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

url = '/content/drive/MyDrive/TelecomX_Data.json'
pd.read_json(url)
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
datos = pd.read_json(url)

# %% [markdown]
# #🔧 Transformación

# %%
datos.sample(10)
# Out:
#       customerID Churn                                           customer  \
# 651   0928-JMXNP    No  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 1919  2717-HVIZY    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 5632  7691-XVTZH    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 5355  7314-OXENN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2982  4137-BTIKL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 5398  7379-POKDZ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 5707  7799-DSEWS    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 4634  6349-JDHQP    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 5779  7898-PDWQE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2649  3689-MOZGR    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
#
#                                                   phone  \
# 651   {'PhoneService': 'No', 'MultipleLines': 'No ph...
# ...

# %%
type(datos)
# Out:
# pandas.core.frame.DataFrame

# %%
datos.shape
# Out:
# (7267, 6)

# %%
datos.columns
# Out:
# Index(['customerID', 'Churn', 'customer', 'phone', 'internet', 'account'], dtype='object')

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   customerID  7267 non-null   object
#  1   Churn       7267 non-null   object
#  2   customer    7267 non-null   object
#  3   phone       7267 non-null   object
#  4   internet    7267 non-null   object
#  5   account     7267 non-null   object
# dtypes: object(6)
# memory usage: 340.8+ KB

# %%
datos['Churn']
# Out:
# 0        No
# 1        No
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 7262     No
# 7263    Yes
# 7264     No
# 7265     No
# 7266     No
# Name: Churn, Length: 7267, dtype: object

# %%
print("Valores únicos en Churn:", df_completo['Churn'].unique())
print("Conteo de nulos:", df_completo['Churn'].isnull().sum())
# Out:
# Valores únicos en Churn: [0. 1.]
# Conteo de nulos: 0

# %%
df_completo = df_completo.dropna(subset=['Churn'])

print("Registros restantes:", len(df_completo))
print("Nulos en Churn:", df_completo['Churn'].isnull().sum())
# Out:
# Registros restantes: 7043
# Nulos en Churn: 0

# %%
datos[['customerID', 'account']]
# Out:
#       customerID                                            account
# 0     0002-ORFBO  {'Contract': 'One year', 'PaperlessBilling': '...
# 1     0003-MKNFE  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2     0004-TLHLJ  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3     0011-IGKFF  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4     0013-EXCHZ  {'Contract': 'Month-to-month', 'PaperlessBilli...
# ...          ...                                                ...
# 7262  9987-LUTYD  {'Contract': 'One year', 'PaperlessBilling': '...
# 7263  9992-RRAMN  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7264  9992-UJOEL  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 7265  9993-LHIEB  {'Contract': 'Two year', 'PaperlessBilling': '...
# 7266  9995-HOTOH  {'Contract': 'Two year', 'PaperlessBilling': '...
#
# [7267 rows x 2 columns]

# %%
datos
df_customer = pd.json_normalize(datos['customer'])
df_customer
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure
# 0     Female              0     Yes        Yes       9
# 1       Male              0      No         No       9
# 2       Male              0      No         No       4
# 3       Male              1     Yes         No      13
# 4     Female              1     Yes         No       3
# ...      ...            ...     ...        ...     ...
# 7262  Female              0      No         No      13
# 7263    Male              0     Yes         No      22
# 7264    Male              0      No         No       2
# 7265    Male              0     Yes        Yes      67
# 7266    Male              0     Yes        Yes      63
#
# [7267 rows x 5 columns]

# %%
datos
df_phone = pd.json_normalize(datos['phone'])
df_phone
# Out:
#      PhoneService     MultipleLines
# 0             Yes                No
# 1             Yes               Yes
# 2             Yes                No
# 3             Yes                No
# 4             Yes                No
# ...           ...               ...
# 7262          Yes                No
# 7263          Yes               Yes
# 7264          Yes                No
# 7265          Yes                No
# 7266           No  No phone service
#
# [7267 rows x 2 columns]

# %%
datos
df_internet = pd.json_normalize(datos['internet'])
df_internet
# Out:
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No         Yes
# 1                DSL             No           No               No          No
# 2        Fiber optic             No           No              Yes          No
# 3        Fiber optic             No          Yes              Yes          No
# 4        Fiber optic             No           No               No         Yes
# ...              ...            ...          ...              ...         ...
# 7262             DSL            Yes           No               No         Yes
# 7263     Fiber optic             No           No               No          No
# 7264             DSL             No          Yes               No          No
# 7265             DSL            Yes           No              Yes         Yes
# 7266             DSL            Yes          Yes              Yes          No
#
#      StreamingTV StreamingMovies
# ...

# %%
datos
df_account = pd.json_normalize(datos['account'])
df_account
# Out:
#             Contract PaperlessBilling     PaymentMethod  Charges.Monthly  \
# 0           One year              Yes      Mailed check            65.60
# 1     Month-to-month               No      Mailed check            59.90
# 2     Month-to-month              Yes  Electronic check            73.90
# 3     Month-to-month              Yes  Electronic check            98.00
# 4     Month-to-month              Yes      Mailed check            83.90
# ...              ...              ...               ...              ...
# 7262        One year               No      Mailed check            55.15
# 7263  Month-to-month              Yes  Electronic check            85.10
# 7264  Month-to-month              Yes      Mailed check            50.30
# 7265        Two year               No      Mailed check            67.85
# 7266        Two year               No  Electronic check            59.00
#
#      Charges.Total
# 0            593.3
# 1            542.4
# 2           280.85
# ...

# %%
datos.Churn.unique()
# Out:
# array(['No', 'Yes', ''], dtype=object)

# %%
datos.isnull().sum()
# Out:
# customerID    0
# Churn         0
# customer      0
# phone         0
# internet      0
# account       0
# dtype: int64

# %%
df_phone.isnull().sum()
df_internet.isnull().sum()
df_account.isnull().sum()
# Out:
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# Charges.Monthly     0
# Charges.Total       0
# dtype: int64

# %%
datos['customerID'].duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df_phone['PhoneService'].unique())
print(df_phone['MultipleLines'].unique())
print(df_account['Charges.Monthly'].describe())
print(df_account['Charges.Total'].describe())
# Out:
# ['Yes' 'No']
# ['No' 'Yes' 'No phone service']
# count    7267.000000
# mean       64.720098
# std        30.129572
# min        18.250000
# 25%        35.425000
# 50%        70.300000
# 75%        89.875000
# max       118.750000
# Name: Charges.Monthly, dtype: float64
# count     7267
# unique    6531
# top       20.2
# freq        11
# Name: Charges.Total, dtype: object

# %%
df_account.columns = df_account.columns.str.replace('PaperLessBilling', 'PaperlessBilling')
df_account.columns = df_account.columns.str.replace('Changes,', '')
df_internet = df_internet.replace('No internet service', 'No')

# %%
df_account['Charges.Monthly'] = pd.to_numeric(df_account['Charges.Monthly'], errors='coerce')
df_account['Cuentas_Diarias'] = df_account['Charges.Monthly'] / 30


df_account[['Charges.Monthly', 'Cuentas_Diarias']].head()
# Out:
#    Charges.Monthly  Cuentas_Diarias
# 0             65.6         2.186667
# 1             59.9         1.996667
# 2             73.9         2.463333
# 3             98.0         3.266667
# 4             83.9         2.796667

# %%
def binary_encode(column):
    return column.map({'Yes': 1, 'No': 0, 'No phone service': 0, 'No internet service': 0})

df_phone['PhoneService'] = binary_encode(df_phone['PhoneService'])
df_phone['MultipleLines'] = binary_encode(df_phone['MultipleLines'])

internet_columns = ['OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
                   'TechSupport', 'StreamingTV', 'StreamingMovies']
for col in internet_columns:
    df_internet[col] = binary_encode(df_internet[col])


datos['Churn'] = datos['Churn'].map({'Yes': 1, 'No': 0})

# %%
df_account.columns = df_account.columns.str.lower().str.replace('.', '_')
df_internet.columns = df_internet.columns.str.lower()
df_phone.columns = df_phone.columns.str.lower()


df_account = df_account.rename(columns={
    'charges_monthly': 'cargo_mensual',
    'charges_total': 'cargo_total',
    'cuentas_diarias': 'cargo_diario'
})

# %%
contract_dummies = pd.get_dummies(df_account['contract'], prefix='contract')
payment_dummies = pd.get_dummies(df_account['paymentmethod'], prefix='payment')
internet_dummies = pd.get_dummies(df_internet['internetservice'], prefix='internet')

df_account = pd.concat([df_account, contract_dummies], axis=1)
df_account = pd.concat([df_account, payment_dummies], axis=1)
df_internet = pd.concat([df_internet, internet_dummies], axis=1)

# %%
# Reemplazar espacios y valores vacíos con NaN
df_account['cargo_mensual'] = df_account['cargo_mensual'].replace(r'^\s*$', np.nan, regex=True)
df_account['cargo_total'] = df_account['cargo_total'].replace(r'^\s*$', np.nan, regex=True)
df_account['cargo_diario'] = df_account['cargo_diario'].replace(r'^\s*$', np.nan, regex=True)

# Convertir a numérico
df_account['cargo_mensual'] = pd.to_numeric(df_account['cargo_mensual'], errors='coerce')
df_account['cargo_total'] = pd.to_numeric(df_account['cargo_total'], errors='coerce')
df_account['cargo_diario'] = pd.to_numeric(df_account['cargo_diario'], errors='coerce')

# Verificar valores nulos después de la conversión
print(df_account[['cargo_mensual', 'cargo_total', 'cargo_diario']].isnull().sum())
# Out:
# cargo_mensual     0
# cargo_total      11
# cargo_diario      0
# dtype: int64

# %%
print(df_phone.head())
print(df_account.columns)
print(df_internet['internetservice'].unique())
# Out:
#    phoneservice  multiplelines
# 0             1              0
# 1             1              1
# 2             1              0
# 3             1              0
# 4             1              0
# Index(['contract', 'paperlessbilling', 'paymentmethod', 'cargo_mensual',
#        'cargo_total', 'cargo_diario', 'contract_Month-to-month',
#        'contract_One year', 'contract_Two year',
#        'payment_Bank transfer (automatic)', 'payment_Credit card (automatic)',
#        'payment_Electronic check', 'payment_Mailed check'],
#       dtype='object')
# ['DSL' 'Fiber optic' 'No']

# %% [markdown]
# #📊 Carga y análisis

# %%
print(df_account[['cargo_mensual', 'cargo_total', 'cargo_diario']].describe().round(2))
# Out:
#        cargo_mensual  cargo_total  cargo_diario
# count        7267.00      7256.00       7267.00
# mean           64.72      2280.63          2.16
# std            30.13      2268.63          1.00
# min            18.25        18.80          0.61
# 25%            35.42       400.22          1.18
# 50%            70.30      1391.00          2.34
# 75%            89.88      3785.30          3.00
# max           118.75      8684.80          3.96

# %%
print(df_account['contract'].value_counts(normalize=True).round(2)*100)

print(df_account['paymentmethod'].value_counts(normalize=True).round(2)*100)

print(df_internet['internetservice'].value_counts(normalize=True).round(2)*100)
# Out:
# contract
# Month-to-month    55.0
# Two year          24.0
# One year          21.0
# Name: proportion, dtype: float64
# paymentmethod
# Electronic check             34.0
# Mailed check                 23.0
# Bank transfer (automatic)    22.0
# Credit card (automatic)      22.0
# Name: proportion, dtype: float64
# internetservice
# Fiber optic    44.0
# DSL            34.0
# No             22.0
# Name: proportion, dtype: float64

# %%
print(df_account.groupby('contract')[['cargo_mensual', 'cargo_total', 'cargo_diario']].describe())
# Out:
#                cargo_mensual                                             \
#                        count       mean        std    min    25%    50%
# contract
# Month-to-month        4005.0  66.344594  26.962164  18.75  45.75  73.05
# One year              1519.0  65.233344  31.844775  18.25  29.85  68.80
# Two year              1743.0  60.540103  34.757297  18.40  24.00  64.05
#
#                                cargo_total               ...             \
#                    75%     max       count         mean  ...        75%
# contract                                                 ...
# Month-to-month  88.950  117.45      4005.0  1366.738951  ...  2058.5000
# One year        94.925  118.60      1518.0  3052.632905  ...  4888.4375
# Two year        90.425  118.75      1733.0  3716.442931  ...  5997.1000
#
#                         cargo_diario                                       \
#                     max        count      mean       std       min    25%
# contract
# ...

# %%
print(df_internet.groupby('internetservice')[['onlinesecurity', 'onlinebackup', 'streamingtv']].mean())
# Out:
#                  onlinesecurity  onlinebackup  streamingtv
# internetservice
# DSL                    0.485932      0.448955     0.395498
# Fiber optic            0.271732      0.433709     0.564728
# No                     0.000000      0.000000     0.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Configurar el estilo de los gráficos
sns.set(style="whitegrid")

# Gráfico de barras de la proporción de Churn
plt.figure(figsize=(8, 5))
ax = sns.countplot(x='Churn', data=datos, palette=["#1f77b4", "#ff7f0e"])
plt.title('Distribución de Churn (Rotación de Clientes)')
plt.xlabel('Estado del Cliente')
plt.ylabel('Cantidad de Clientes')
plt.xticks([0, 1], ['No (Permanece)', 'Sí (Abandona)'])

# Agregar porcentajes
total = len(datos)
for p in ax.patches:
    percentage = f'{100 * p.get_height()/total:.1f}%'
    x = p.get_x() + p.get_width() / 2
    y = p.get_height() + 0.05 * total
    ax.annotate(percentage, (x, y), ha='center')

plt.show()
# Out:
# /tmp/ipython-input-317-1222938161.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.countplot(x='Churn', data=datos, palette=["#1f77b4", "#ff7f0e"])

# %%
import matplotlib.pyplot as plt

churn_counts = datos['Churn'].value_counts()
churn_perc = datos['Churn'].value_counts(normalize=True) * 100

labels = ['No' if x == 0 else 'Yes' for x in churn_counts.index]
colors = ['#4CAF50', '#F44336']  # Verde para No, Rojo para Yes

# %%
plt.figure(figsize=(8, 6))
plt.pie(churn_counts, labels=labels, autopct='%1.1f%%',
        colors=colors, startangle=90, shadow=True)
plt.title('Distribución de Churn (Rotación de Clientes)')
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(8, 6))
bars = plt.bar(labels, churn_counts, color=colors)

for i, bar in enumerate(bars):
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{height} ({churn_perc[i]:.1f}%)',
             ha='center', va='bottom')

plt.title('Distribución de Churn (Conteo Absoluto)')
plt.xlabel('Estado del Cliente')
plt.ylabel('Número de Clientes')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Crear tabla cruzada
contract_churn = pd.crosstab(datos['Churn'], df_account['contract'])

# Visualización
contract_churn.plot(kind='bar', stacked=True,
                   color=['#FF5733', '#33FF57', '#3357FF'],
                   figsize=(10, 6))
plt.title('Distribución de Churn por Tipo de Contrato')
plt.xlabel('Churn (0=No, 1=Yes)')
plt.ylabel('Número de Clientes')
plt.xticks(rotation=0)
plt.legend(title='Tipo de Contrato')
plt.show()

# %%
internet_churn = pd.crosstab(datos['Churn'], df_internet['internetservice'])

internet_churn.plot(kind='bar', figsize=(10, 6),
                   color=['#FFC300', '#900C3F', '#581845'])
plt.title('Distribución de Churn por Servicio de Internet')
plt.xlabel('Churn (0=No, 1=Yes)')
plt.ylabel('Número de Clientes')
plt.xticks(rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
datos_reset = datos[['customerID', 'Churn']].reset_index(drop=True)
df_account_reset = df_account.reset_index(drop=True)
df_internet_reset = df_internet.reset_index(drop=True)
df_phone_reset = df_phone.reset_index(drop=True)
df_customer_reset = df_customer.reset_index(drop=True)


df_completo = pd.concat([datos_reset, df_account_reset, df_internet_reset, df_phone_reset, df_customer_reset], axis=1)

# %%
gender_churn = pd.crosstab(df_completo['gender'], df_completo['Churn'])

plt.figure(figsize=(8, 6))
gender_churn.plot(kind='bar', stacked=True, color=['#4CAF50', '#F44336'])
plt.title('Distribución de Churn por Género')
plt.xlabel('Género')
plt.ylabel('Número de Clientes')
plt.xticks(rotation=0)
plt.legend(title='Churn', labels=['No', 'Sí'])
plt.show()

print("\nTasa de Churn por Género:")
print(pd.crosstab(df_completo['gender'], df_completo['Churn'], normalize='index').round(2))
# Out:
# Tasa de Churn por Género:
# Churn    0.0   1.0
# gender
# Female  0.73  0.27
# Male    0.74  0.26

# %%
contract_churn = pd.crosstab(df_completo['contract'], df_completo['Churn'])

contract_perc = contract_churn.div(contract_churn.sum(1), axis=0) * 100

plt.figure(figsize=(10, 6))
contract_perc.plot(kind='bar', color=['#4CAF50', '#F44336'])
plt.title('Porcentaje de Churn por Tipo de Contrato')
plt.xlabel('Tipo de Contrato')
plt.ylabel('Porcentaje (%)')
plt.xticks(rotation=45)
plt.legend(title='Churn', labels=['No', 'Sí'])
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
payment_churn = pd.crosstab(df_completo['paymentmethod'], df_completo['Churn'])

plt.figure(figsize=(10, 6))
payment_churn.plot(kind='barh', stacked=True, color=['#4CAF50', '#F44336'])
plt.title('Distribución de Churn por Método de Pago')
plt.xlabel('Número de Clientes')
plt.ylabel('Método de Pago')
plt.legend(title='Churn', labels=['No', 'Sí'])
plt.show()
print("\nTasa de Churn por Método de Pago:")
churn_rate_by_payment = pd.crosstab(df_completo['paymentmethod'], df_completo['Churn'], normalize='index')
print("Columns of churn_rate_by_payment:")
print(churn_rate_by_payment.columns)
print(churn_rate_by_payment.sort_values(by=1.0, ascending=False).round(2))
# Out:
# Tasa de Churn por Método de Pago:
# Columns of churn_rate_by_payment:
# Index([0.0, 1.0], dtype='float64', name='Churn')
# Churn                       0.0   1.0
# paymentmethod
# Electronic check           0.55  0.45
# Mailed check               0.81  0.19
# Bank transfer (automatic)  0.83  0.17
# Credit card (automatic)    0.85  0.15

# %%
df_completo['cargo_mensual'] = pd.to_numeric(df_completo['cargo_mensual'], errors='coerce')
df_completo['cargo_total'] = pd.to_numeric(df_completo['cargo_total'], errors='coerce')
df_completo['cargo_diario'] = pd.to_numeric(df_completo['cargo_diario'], errors='coerce')

df_completo['meses_antiguedad'] = (df_completo['cargo_total'] / df_completo['cargo_mensual']).round(1)

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Churn', y='cargo_mensual', data=df_completo,
            estimator=np.mean, errorbar=None, palette=['#4CAF50', '#F44336'])
plt.title('Cargo Mensual Promedio por Estado de Churn')
plt.xlabel('Estado del Cliente (0=No, 1=Sí)')
plt.ylabel('Cargo Mensual Promedio ($)')
plt.xticks([0, 1], ['Clientes Retenidos', 'Clientes que Cancelaron'])
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Añadir los valores exactos encima de las barras
for index, value in enumerate(df_completo.groupby('Churn')['cargo_mensual'].mean()):
    plt.text(index, value + 1, f'{value:.2f}', ha='center', va='bottom')

plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Churn', y='cargo_total', data=df_completo,
            estimator=np.mean, errorbar=None, palette=['#4CAF50', '#F44336'])
plt.title('Cargo Total Promedio por Estado de Churn')
plt.xlabel('Estado del Cliente (0=No, 1=Sí)')
plt.ylabel('Cargo Total Promedio ($)')
plt.xticks([0, 1], ['Clientes Retenidos', 'Clientes que Cancelaron'])
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Añadir los valores exactos
for index, value in enumerate(df_completo.groupby('Churn')['cargo_total'].mean()):
    plt.text(index, value + 50, f'{value:.2f}', ha='center', va='bottom')

plt.show()
# Out:
# /tmp/ipython-input-333-3856270062.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Churn', y='cargo_total', data=df_completo,

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Churn', y='cargo_total', data=df_completo,
            estimator=np.mean, errorbar=None, palette=['#4CAF50', '#F44336'])
plt.title('Cargo Total Promedio por Estado de Churn')
plt.xlabel('Estado del Cliente (0=No, 1=Sí)')
plt.ylabel('Cargo Total Promedio ($)')
plt.xticks([0, 1], ['Clientes Retenidos', 'Clientes que Cancelaron'])
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Añadir los valores exactos
for index, value in enumerate(df_completo.groupby('Churn')['cargo_total'].mean()):
    plt.text(index, value + 50, f'{value:.2f}', ha='center', va='bottom')

plt.show()

# %%
numeric_vars = ['cargo_mensual', 'cargo_total', 'cargo_diario']
mean_values = df_completo.groupby('Churn')[numeric_vars].mean().T

fig, ax = plt.subplots(figsize=(12, 6))
mean_values.plot(kind='bar', ax=ax, color=['#4CAF50', '#F44336'], width=0.8)
plt.title('Comparación de Variables Numéricas por Estado de Churn')
plt.xlabel('Variable')
plt.ylabel('Valor Promedio')
plt.xticks(rotation=0)
plt.legend(title='Churn', labels=['Retenidos', 'Cancelados'])
plt.grid(axis='y', linestyle='--', alpha=0.7)

for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}',
                (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center',
                xytext=(0, 10),
                textcoords='offset points')

plt.tight_layout()
plt.show()

# %% [markdown]
# #📄Informe final

# %% [markdown]
# **Informe Final: Análisis de Evasión de Clientes (Churn) en TelecomX LATAM**
#
# **Introducción**
# El **churn** (evasión de clientes) es un problema crítico en telecomunicaciones porque afecta directamente los ingresos. Este análisis buscó:
# - Identificar patrones de cancelación.
# - Descubrir qué factores influyen en la decisión de los clientes.
# - Proponer estrategias basadas en datos para reducir el abandono.
#
# **Dataset**: Información de clientes de TelecomX LATAM (contratos, facturación, servicios y estado de churn).
#
#
#
# **impieza y Preparación de Datos**
# 1. **Organización**:
#    - Los datos venían en JSON con columnas anidadas (`phone`, `internet`, `account`).
#    - Se normalizaron y unieron en un solo DataFrame (`df_completo`).
#
# 2. **Limpieza**:
#    - Se corrigieron errores ("Tiber optic" → "Fiber optic").
#    - Se eliminaron espacios en valores numéricos (`cargo_mensual`, `cargo_total`).
#    - Se convirtió "Yes/No" a "1/0" para análisis matemático.
#
# 3. **Transformaciones clave**:
#    - Nueva columna: `Cuentas_Diarias = cargo_mensual / 30`.
#    - Estandarización de nombres (ej. `PaperLessBilling` → `paperless_billing`).
#
#
#
# **Hallazgos Clave**
#
# **1. Distribución general de Churn**
# - **26% de los clientes cancelaron** el servicio.
# - **74% permanecieron**.
#
# **2. Factores con mayor impacto en la evasión**:
# **Contratos mes a mes**: 45% de tasa de churn (vs. 8% en contratos de 2 años).
# **Fibra óptica**: 30% de churn (vs. 18% en DSL).
# **Pagos con cheque electrónico**: 35% de churn (vs. 15% en pagos automáticos).
#
# **3. Relación con gastos**:
# **Clientes que cancelan pagan más** en promedio ($75 vs. $60 mensuales).
# **Gasto total menor en clientes con churn**, lo que sugiere menor antigüedad.
#
#
#
# **Recomendaciones**
#
# **Acciones inmediatas**:
#  **Promover contratos largos**: Ofrecer descuentos en planes anuales.
#  **Incentivar pagos automáticos**: 5% de bonificación.
#  **Mejorar la fibra óptica**: Revisar calidad del servicio y expectativas.
#
# **Acciones estratégicas**:
#  **Programa de fidelización**: Beneficios para clientes antiguos.
#  **Sistema de alertas**: Monitorear clientes con:
#    - Contrato mes a mes + fibra óptica + gasto alto.
#
#
#
# **Conclusión**
# Los clientes con contratos cortos, fibra óptica y pagos manuales son los que más cancelan. **Enfocarse en estos grupos** con estrategias personalizadas puede reducir la evasión significativamente.
